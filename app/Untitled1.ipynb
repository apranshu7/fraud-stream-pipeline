# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json, to_timestamp, window

spark = (SparkSession.builder
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.3.2")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate())
spark.sparkContext.setLogLevel("WARN")
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-2f9385e0-9398-44b1-9d91-d9b1dc2056bb;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.3.2 in central
# 	found io.delta#delta-storage;3.3.2 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 107ms :: artifacts dl 4ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.3.2 from central in [default]
# 	io.delta#delta-storage;3.3.2 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# ...

# %%
df = spark.read.format("delta").load("/opt/delta/transactions_running_prod")
final_df = df.select(col("window.start").alias("start_time"),col("window.end").alias("end_time"),col("user_id"),col("count"))
final_df.orderBy("start_time","user_id").limit(200).toPandas()
# Out:
# 26/07/03 17:19:27 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#              start_time            end_time  user_id  count
# 0   2026-06-28 02:25:00 2026-06-28 02:26:00  user_15      1
# 1   2026-06-28 02:25:00 2026-06-28 02:26:00  user_24      1
# 2   2026-06-28 02:25:00 2026-06-28 02:26:00  user_34      1
# 3   2026-06-28 02:25:00 2026-06-28 02:26:00  user_36      3
# 4   2026-06-28 02:25:00 2026-06-28 02:26:00  user_38      1
# ..                  ...                 ...      ...    ...
# 195 2026-07-03 16:03:00 2026-07-03 16:04:00  user_10      1
# 196 2026-07-03 16:03:00 2026-07-03 16:04:00  user_11      1
# 197 2026-07-03 16:03:00 2026-07-03 16:04:00  user_12      3
# 198 2026-07-03 16:03:00 2026-07-03 16:04:00  user_14      2
# 199 2026-07-03 16:03:00 2026-07-03 16:04:00  user_15      1
#
# [200 rows x 4 columns]
